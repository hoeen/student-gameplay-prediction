# %%
import pickle
import matplotlib.pyplot as plt

# %%
name = 'tunic.historicalsociety.closet_screen.pkl'
fig = pickle.load(open(f'../figures/tochoose_cluster/{name}', 'rb'))
# plt.ylim(0, 1e8)
fig.show()
